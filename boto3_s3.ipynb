# %%
# %pylab inline

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd
import boto3
import io
import gzip

# %%
s3 = boto3.resource('s3')

# %%
b = s3.Bucket('houdy-dku-bucket')
for my_bucket_object in b.objects.all():
    print(my_bucket_object)
# Out:
# s3.ObjectSummary(bucket_name='houdy-dku-bucket', key=u'dataiku/APPASRECIPE/prices_indicators/out-s0.csv.gz')
# s3.ObjectSummary(bucket_name='houdy-dku-bucket', key=u'dataiku/HOUSEPRICEPREDICTION/Residents_Profiles_filtered/out-s0.csv.gz')
# s3.ObjectSummary(bucket_name='houdy-dku-bucket', key=u'dataiku/HOUSEPRICEPREDICTION/melb_data_prepared/out-s0.csv.gz')
# s3.ObjectSummary(bucket_name='houdy-dku-bucket', key=u'dataiku/NESTLE/Sales_by_store_copy/E/out-s0.csv.gz')
# s3.ObjectSummary(bucket_name='houdy-dku-bucket', key=u'dataiku/NESTLE/Sales_by_store_copy/N/out-s0.csv.gz')
# s3.ObjectSummary(bucket_name='houdy-dku-bucket', key=u'dataiku/NESTLE/Sales_by_store_copy/S/out-s0.csv.gz')
# s3.ObjectSummary(bucket_name='houdy-dku-bucket', key=u'dataiku/NESTLE/Sales_by_store_copy/W/out-s0.csv.gz')
# s3.ObjectSummary(bucket_name='houdy-dku-bucket', key=u'dataiku/NESTLE/store_income/N/out-s0.csv.gz')
# ...

# %%
s3 = boto3.resource('s3')
key='dataiku/NESTLE/Sales_by_store_copy/N/out-s0.csv.gz'
obj = s3.Object('houdy-dku-bucket',key)
n = obj.get()['Body'].read()
gzipfile = io.BytesIO(n)
gz = gzip.GzipFile(fileobj=gzipfile)
df = pd.read_csv(gz, dtype=str, sep='\t')

# %%
df
# Out:
#      StoreID Income AgeGroup1 AgeGroup2 AgeGroup3 PopulationSize StoreRating Competitor1 Competitor2 Product PricePerUnit Sales
# 0          1  63000        35        38        27           2164           4           1           0       A         1.05   323
# 1          1  63000        35        38        27           2164           4           1           0       B         1.15   372
# 2          5  70000        27        37        36           4380           3           0           0       A         1.05   601
# 3          5  70000        27        37        36           4380           3           1           0       B         1.15   684
# 4         11  71000        35        31        34           9568           5           0           1       A         1.05  1064
# 5         11  71000        35        31        34           9568           5           1           0       B         1.15  1200
# ...
